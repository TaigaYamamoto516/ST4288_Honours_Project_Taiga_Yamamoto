# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir('/content/drive/MyDrive/MMD-GAN-PyTorch')

# %%
# !pip install lmdb

# %%
#Original: Original MMD GAN, LM: MMD GAN LM for the discriminator

# !chmod +x run_exp_LM_D_Original.sh
# !./run_exp_LM_D_Original.sh cifar10 Adam Original

#mnist/celeba/cifar10/lsum
#Adagrad/Adam/RMSprop/SGD/NAdam
#Original/LM

# %%
#Original: MMD GAN Clipping, LM: MMD GAN Clipping then LM

# !chmod +x run_exp_LM_D_CP.sh
# !./run_exp_LM_D_CP.sh cifar10 Adam LM

#mnist/celeba/cifar10/lsum
#Adagrad/Adam/RMSprop/SGD/NAdam
#Original/LM

# %%
#LM: MMD GAN LM then Clipping

# !chmod +x run_exp_LM_D_LMCP.sh
# !./run_exp_LM_D_LMCP.sh cifar10 Adam LM

#mnist/celeba/cifar10/lsum
#Adagrad/Adam/RMSprop/SGD/NAdam
#LM (Use LM)

# %%
#LM: MMD GAN LM for Both with Reset of running extremum

# !chmod +x run_exp_LM_Both.sh
# !./run_exp_LM_Both.sh cifar10 Adam LM

#mnist/celeba/cifar10/lsum
#Adagrad/Adam/RMSprop/SGD/NAdam
#LM (Use LM)

# %%
#LM: MMD GAN LM for Both with No Reset of ruunning extremum

# !chmod +x run_exp_LM_Both_NoReset.sh
# !./run_exp_LM_Both_NoReset.sh cifar10 Adam LM

#mnist/celeba/cifar10/lsum
#Adagrad/Adam/RMSprop/SGD/NAdam
#LM (Use LM)
