# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/pytorch-wgan')

# %%
# !python main.py --model WGAN-GP \
               --is_train True \
               --download True \
               --dataroot /content/drive/MyDrive/MMD-GAN-PyTorch/data/cifar10 \
               --dataset cifar \
               --generator_iters 15000 \
               --cuda True \
               --batch_size 64 \
               --optimizer Adam \
               --lm IKSA
